# %%
import requests

# %%
headers = {
    'user-agent': '',
    # 'content-type': '', 자동 삽입
}
requests.post('', data={}, json={})

# data -> 키=값 -> header에 content-type: x-www-form-urlencoded 삽입
# json -> {}   -> hedaer에 content-type: application/json 삽입

# %%
URL = 'https://golmok.seoul.go.kr/region/selectStoreCount.json'

# payload_str = 'stdrYyCd=2026&stdrSlctQu=sameQu&stdrQuCd=1&stdrMnCd=202606&selectTerm=quarter&svcIndutyCdL=CS000000&svcIndutyCdM=all&stdrSigngu=11&selectInduty=1&infoCategory=store'
# payload = [p.split('=') for p in payload_str.split('&')]
# payload = {k: v for k, v in payload}

payload = {
    'stdrYyCd': '2026',
    'stdrSlctQu': 'sameQu',
    'stdrQuCd': '1',
    # 'stdrMnCd': '202606',
    'selectTerm': 'quarter',
    'svcIndutyCdL': 'CS000000',
    'svcIndutyCdM': 'all',
    'stdrSigngu': '11',
    'selectInduty': '1',
    # 'infoCategory': 'store'
}
# 키=값&키=값 형태
res = requests.post(URL, data=payload)
res.status_code
# Out:
# 200

# %%
res.json()
# Out:
# [{'NM': '서울시 전체',
#   'CD': '11',
#   'GUBUN': 'si',
#   'FIRST_TOT': 659669,
#   'FIRST_NOR': 604133,
#   'FIRST_FRC': 55536,
#   'SECOND_TOT': 640498,
#   'SECOND_NOR': 586507,
#   'SECOND_FRC': 53991,
#   'THIRD_TOT': 627644,
#   'THIRD_NOR': 575619,
#   'THIRD_FRC': 52025},
#  {'NM': '종로구',
#   'CD': '11110',
#   'GUBUN': 'gu',
#   'FIRST_TOT': 25422,
#   'FIRST_NOR': 23768,
#   'FIRST_FRC': 1654,
#   'SECOND_TOT': 25045,
#   'SECOND_NOR': 23414,
#   'SECOND_FRC': 1631,
#   'THIRD_TOT': 24775,
#   'THIRD_NOR': 23208,
#   'THIRD_FRC': 1567},
#  {'NM': '청운효자동',
#   'CD': '11110515',
#   'GUBUN': 'dong',
#   'FIRST_TOT': 946,
#   'FIRST_NOR': 915,
#   'FIRST_FRC': 31,
#   'SECOND_TOT': 935,
#   'SECOND_NOR': 907,
#   'SECOND_FRC': 28,
#   'THIRD_TOT': 946,
#   'THIRD_NOR': 917,
#   'THIRD_FRC': 29},
#  {'NM': '사직동',
#   'CD': '11110530',
#   'GUBUN': 'dong',
#   'FIRST_TOT': 2851,
#   'FIRST_NOR': 2649,
#   'FIRST_FRC': 202,
#   'SECOND_TOT': 2856,
#   'SECOND_NOR': 2649,
# ...

# %%
payload
# Out:
# {'stdrYyCd': '2026',
#  'stdrSlctQu': 'sameQu',
#  'stdrQuCd': '1',
#  'stdrMnCd': '202606',
#  'selectTerm': 'quarter',
#  'svcIndutyCdL': 'CS000000',
#  'svcIndutyCdM': 'all',
#  'stdrSigngu': '11',
#  'selectInduty': '1',
#  'infoCategory': 'store'}

# %%
class Session:
    headers = {}
    cookies = {}

    def request(self) -> requests.Response: 
        ...

    def get(self):

        res = self.request()

        # self.headers.update(res.headers)
        self.cookies.update(dict(res.cookies))

# %%
s = requests.Session()

# %%
cursor = ''

for _ in range(10):
    res = requests.get(params={'nextCursor': cursor})

    cursor = res.json()['nextCursor']

# %% [markdown]
# ### 예제
#
# - 국가통계포털 사이트 수집

# %%
# %-encoding된 것 decoding 하는
from urllib.parse import unquote, quote

URL = 'https://kosis.kr/statHtml/html.do'

payload_str = 'jsonStr=&orgId=101&tblId=DT_1L9U039&language=ko&file=&analText=&scrId=&fieldList=%5B%7B%22targetId%22%3A%22PRD%22%2C%22targetValue%22%3A%22%22%2C%22prdValue%22%3A%22Q%2C202404%2C202403%2C%40%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T110%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T120%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22ITM_ID%22%2C%22targetValue%22%3A%22T150%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%222%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%224%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%227%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22A%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B2%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B4%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B5%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B6%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B7%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22B8%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22D%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22F%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22H%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22J%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22K%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22L%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22M%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22N%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22O%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22P%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22Q%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22S%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22T%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22U%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22W%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22Y1%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22Y2%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22Y3%22%2C%22prdValue%22%3A%22%22%7D%2C%7B%22targetId%22%3A%22OV_L1_ID%22%2C%22targetValue%22%3A%22Y4%22%2C%22prdValue%22%3A%22%22%7D%5D&colAxis=TIME%2CITEM&rowAxis=GSH&isFirst=Y&contextPath=%2FstatHtml&ordColIdx=&ordType=&logSeq=&vwCd=MT_ZTITLE&listId=G_A_10_003_004&connPath=MT_ZTITLE&statId=1962009&pub=2&pubLog=4&viewKind=1&viewSubKind=&doAnal=N&analType=&analCmpr=&analTime=&analCombo=&originData=&analClass=&analItem=&obj_var_id=&itm_id=&mode=&dataOpt=ko&noSelect=&view=table&mobChk=false&analWithCHGRATE=&defaulPeriodArr=&defaultClassArr=&defaultItmArr=&existStblCmmtKor=Y&existStblCmmtEng=N&classAllArr=%5B%7B%22objVarId%22%3A%22GSH%22%2C%22ovlSn%22%3A%221%22%7D%5D&classSet=%5B%7B%22objVarId%22%3A%22GSH%22%2C%22ovlSn%22%3A%221%22%2C%22visible%22%3A%22true%22%7D%5D&selectAllFlag=N&selectTimeRangeCnt=&periodStr=Q%23Y&funcPrdSe=&tblNm=%EA%B0%80%EA%B5%AC%EB%8B%B9+%EC%9B%94%ED%8F%89%EA%B7%A0+%EA%B0%80%EA%B3%84%EC%88%98%EC%A7%80+(%EB%8F%84%EC%8B%9C%2C1%EC%9D%B8%EC%9D%B4%EC%83%81%2C%EC%8B%A4%EC%A7%88)&tblEngNm=Average+monthly+income+%26+expenditure+(real%2C+urban+households)&isChangedDataOpt=&itemMultiply=&dimCo=&dbUser=NSI.&usePivot=N&isChangedTableType=N&isChangedPeriodCo=N&isChangedPrdSort=N&p_chkStatus=&p_objVarId=&p_lvl=&p_logicFlag=&p_classAllChkYn=N&p_classAllSelectYn=N&useAddFuncLog=&chargerLvl=&st=&new_win=&first_open=&debug=&maxCellOver=&reqCellCnt=0&inheritYn=N&originOrgId=&originTblId=&pubSeType=&relChkOrgId=&relChkTblId=&highLightStr=&markType=&docId=&itmNm=&cmmtChk=&labelOriginData=%EC%9B%90%EC%9E%90%EB%A3%8C+%ED%95%A8%EA%BB%98+%EB%B3%B4%EA%B8%B0&diviSearchYn=N&orderStr=OV_L1_ID%2CTIME%2CCHAR_ITM_ID&startNum=1&endNum=174&lastChk=N&colClsAt=N&analyzable=true&tmprScrId=&expDash=Y&downGridFileType=xlsx&downGridCellMerge=Y&downGridMeta=Y&downSort=asc&pointType=screen&downLargeFileType=excel&downLargeExprType=1&downLargeSort=asc&naviInfo=tabItemText&naviInfo=GSH&naviInfo=tabTimeText&tableType=default&dataOpt2=ko&periodCo=&prdSort=asc&compValue=&compValue01=&compValue02='
payload = [p.split('=') for p in payload_str.split('&')]
payload = {k: unquote(v) for k, v in payload}

res = requests.post(URL, 
                    headers={
                        'referer': 'https://kosis.kr/statHtml/statHtmlContent.do'
                        },
                    data=payload)

res.status_code

# res.json()['result'][0]
# Out:
# 200

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(res.json()['result'][0], 'html.parser')

trs = soup.select('tbody tr')

# %%
def get_text(tag):
    return tag.text.strip() if tag else ''

datas = []
for tr in trs:
    tds = tr.select('td')

    row_header = get_text(tds[0])

    datas.append({
        '항목': row_header,
        '2024.3Q 전체가구': get_text(tds[1]),
        '2024.3Q 근로자가구': get_text(tds[2]),
        '2024.3Q 근로자외가구': get_text(tds[3]),
        '2024.4Q 전체가구': get_text(tds[4]),
        '2024.4Q 근로자가구': get_text(tds[5]),
        '2024.4Q 근로자외가구': get_text(tds[6]),
    })
